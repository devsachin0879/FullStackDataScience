# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\Sachin Dev\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ##### Basic Scatter plot

# %%
x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y)
plt.show()

# %%
x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

##chanfge size of dots
plt.scatter(x,y, s=100)
plt.show()

# %% [markdown]
# ##### Change Color

# %%
x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y, s=100, c='green')
plt.show()

# %% [markdown]
# ##### Change Marker

# %%
x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y, s=100, c='green', marker='X')
plt.show()

# %% [markdown]
# ##### Add edges to circles and opacity

# %%
x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y, s=100, c='green', edgecolor='black', linewidth=1, alpha=0.75)
plt.show()

# %% [markdown]
# ##### Multiple colors and sizes of circles

# %%
x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]
colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]

plt.style.use('seaborn')
plt.scatter(x,y, s=100, c=colors, edgecolor='black', linewidth=1, alpha=0.75)
plt.show()
# Out:
# <ipython-input-11-4151e708ef20>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
#### color maps

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]
colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]


plt.scatter(x,y, s=100, c=colors,cmap="Greens", edgecolor='black', linewidth=1, alpha=0.75)
plt.show()

# %%
#### color bar legend

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]
colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]


plt.scatter(x,y, s=100, c=colors,cmap="Greens", edgecolor='black', linewidth=1, alpha=0.75)

#### color bar
cbar = plt.colorbar()
cbar.set_label('Satisfaction')

plt.show()

# %%
#### color bar legend

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]
colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]
sizes = [209, 486, 381, 255, 191, 315, 185, 228, 174,538, 239, 394, 399, 153, 273, 293, 436, 501, 397, 539]

plt.scatter(x,y, s=sizes, c=colors,cmap="Greens", edgecolor='black', linewidth=1, alpha=0.75)

#### color bar
cbar = plt.colorbar()
cbar.set_label('Satisfaction')

plt.show()

# %% [markdown]
# ##### Real world Data

# %%
data = pd.read_csv("data_scatter.csv")
data.head()
# Out:
#    view_count   likes  ratio
# 0     8036001  324742  96.91
# 1     9378067  562589  98.19
# 2     2182066  273650  99.38
# 3     6525864   94698  96.25
# 4     9481284  582481  97.22

# %%
view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']

plt.figure(figsize=(10,7))
plt.scatter(view_count, likes, edgecolor='black', linewidth=1, alpha=0.75)
plt.title("Trending Youtube Videos")
plt.xlabel("View Count")
plt.ylabel("Total Likes")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Log Scale

# %%
view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']

plt.figure(figsize=(10,7))
plt.scatter(view_count, likes, edgecolor='black', linewidth=1, alpha=0.75)

### logscale
plt.xscale('log')
plt.yscale('log')

plt.title("Trending Youtube Videos")
plt.xlabel("View Count")
plt.ylabel("Total Likes")

plt.tight_layout()
plt.show()

# %%
view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']

plt.figure(figsize=(10,7))

plt.scatter(view_count, likes,c=ratio,cmap='summer', edgecolor='black', linewidth=1, alpha=0.75)

cbar = plt.colorbar()
cbar.set_label('Like/Dislike Ratio')

### logscale
plt.xscale('log')
plt.yscale('log')

plt.title("Trending Youtube Videos")
plt.xlabel("View Count")
plt.ylabel("Total Likes")

plt.tight_layout()
plt.show()
