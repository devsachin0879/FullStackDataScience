# %% [markdown]
# **Question1.**
#
# Write a function that stutters a word as if someone is struggling to read it. The
# first two letters are repeated twice with an ellipsis ... and space after each, and then the
# word is pronounced with a question mark ?.<br>
# Examples<br>
# stutter(&quot;incredible&quot;) ➞ &quot;in... in... incredible?&quot;<br>
# stutter(&quot;enthusiastic&quot;) ➞ &quot;en... en... enthusiastic?&quot;<br>
# stutter(&quot;outstanding&quot;) ➞ &quot;ou... ou... outstanding?&quot;<br>
#
# Hint :- Assume all input is in lower case and at least two characters long.<br>

# %%
def gen_str():
    s = input("Please enter a word: ")
    out = (s[0:2] + "... ")*2 + s +"?"
    print(f"stutter{s} ==> {out}")

# %%
gen_str()
# Out:
# Please enter a word: incredible
# stutterincredible ==> in... in... incredible?

# %%
gen_str()
# Out:
# Please enter a word: enthusiastic
# stutterenthusiastic ==> en... en... enthusiastic?

# %%
gen_str()
# Out:
# Please enter a word: outstanding
# stutteroutstanding ==> ou... ou... outstanding?

# %% [markdown]
# **Question 2.**
#
# Create a function that takes an angle in radians and returns the corresponding angle in degrees rounded to one decimal place.<br>
# Examples<br>
# radians_to_degrees(1) ➞ 57.3<br>
# radians_to_degrees(20) ➞ 1145.9<br>
# radians_to_degrees(50) ➞ 2864.8<br>

# %%
import math
def rad_to_deg():
    n = int(input("Please enter angle in radians: "))
    out = n * (180/math.pi)
    print(f"{n} radian(s) ==> {out:.1f} in degrees")

# %%
rad_to_deg()
# Out:
# Please enter angle in radians: 1
# 1 radian(s) ==> 57.3 in degrees

# %%
rad_to_deg()
# Out:
# Please enter angle in radians: 20
# 20 radian(s) ==> 1145.9 in degrees

# %%
rad_to_deg()
# Out:
# Please enter angle in radians: 50
# 50 radian(s) ==> 2864.8 in degrees

# %% [markdown]
# **Question 3.**
#
# In this challenge, establish if a given integer num is a Curzon number. If 1 plus 2 elevated to num is exactly divisible by 1 plus 2 multiplied by num, then num is a Curzon number.<br>
# Given a non-negative integer num, implement a function that returns True if num is a Curzon number, or False otherwise.<br>
#
# Examples<br>
# is_curzon(5) ➞ True<br>
# 2 ** 5 + 1 = 33<br>
# 2 * 5 + 1 = 11<br>
# 33 is a multiple of 11<br>
#
# is_curzon(10) ➞ False<br>
# 2 ** 10 + 1 = 1025<br>
# 2 * 10 + 1 = 21<br>
# 1025 is not a multiple of 21<br>
#
# is_curzon(14) ➞ True<br>
# 2 ** 14 + 1 = 16385<br>
# 2 * 14 + 1 = 29<br>
# 16385 is a multiple of 29<br>

# %%
def is_curzon():
    n = int(input("Please eneter a number: "))
    a = (2**n) + 1
    b = (2*5) + 1
    if a%b == 0:
        print(f"{a} is a multiple of {b}")
    else:
        print(f"{a} is not a multiple of {b}")

# %%
is_curzon()
# Out:
# Please eneter a number: 5
# 33 is a multiple of 11

# %%
is_curzon()
# Out:
# Please eneter a number: 10
# 1025 is not a multiple of 11

# %%
is_curzon()
# Out:
# Please eneter a number: 14
# 16385 is not a multiple of 11

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
def area_of_hex():
    s = int(input("Please enter the length of the side: "))
    area = (3*(math.sqrt(3))*(s**2))/2
    print(f"area_of_hexagon({s}) ==> {area:.1f}")

# %%
area_of_hex()
# Out:
# Please enter the length of the side: 1
# area_of_hexagon(1) ==> 2.6

# %%
area_of_hex()
# Out:
# Please enter the length of the side: 2
# area_of_hexagon(2) ==> 10.4

# %%
area_of_hex()
# Out:
# Please enter the length of the side: 3
# area_of_hexagon(3) ==> 23.4

# %% [markdown]
# **Question 5.**
#
# Create a function that returns a base-2 (binary) representation of a base-10 (decimal) string number. To convert is simple: ((2) means base-2 and (10) means base-10) 010101001(2) = 1 + 8 + 32 + 128.<br>
# Going from right to left, the value of the most right bit is 1, now from that every bit to the left will be x2 the value, value of an 8 bit binary numbers are (256, 128, 64, 32, 16, 8, 4, 2, 1).<br>
# Examples<br>
# binary(1) ➞ "1"<br>
# 1* 1 = 1
#
# binary(5) ➞ "101"<br>
# 1* 1 + 1* 4 = 5
#
# binary(10) ➞ "1010"<br>
# 1* 2 + 1* 8 = 10

# %%
def get_binary():
    n = int(input("Enter a number: "))
    out = bin(n).replace('0b','')
    print(f"binary({n}) ==> {out}")

# %%
get_binary()
# Out:
# Enter a number: 5
# binary(5) ==> 101

# %%
get_binary()
# Out:
# Enter a number: 1
# binary(1) ==> 1

# %%
get_binary()
# Out:
# Enter a number: 10
# binary(10) ==> 1010
