# %%
import pandas as pd

# %%
df = pd.read_csv("PLayers_NBA.csv")

# %%
df.head()
# Out:
#     Season   Age                                     Tm  \
# 0  2008-09  19.0  Did Not Play (other pro league—Spain)
# 1  2009-10  20.0                                    OKC
# 2  2010-11  21.0                                    OKC
# 3  2011-12  22.0                                    OKC
# 4  2012-13  23.0                                    OKC
#
#                                       Lg  \
# 0  Did Not Play (other pro league—Spain)
# 1                                    NBA
# 2                                    NBA
# 3                                    NBA
# 4                                    NBA
#
#                                      Pos  \
# 0  Did Not Play (other pro league—Spain)
# 1                                     PF
# 2                                     PF
# 3                                     PF
# 4                                     PF
#
#                                        G  \
# 0  Did Not Play (other pro league—Spain)
# ...

# %%
### store data to pickle format
df.to_pickle("player_nba_pickle")

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Pandas_1.ipynb',
#  'Pandas_2.ipynb',
#  'PLayers_NBA.csv',
#  'player_nba_pickle']

# %%
## read from pickle
pd.read_pickle("player_nba_pickle").head()
# Out:
#     Season   Age                                     Tm  \
# 0  2008-09  19.0  Did Not Play (other pro league—Spain)
# 1  2009-10  20.0                                    OKC
# 2  2010-11  21.0                                    OKC
# 3  2011-12  22.0                                    OKC
# 4  2012-13  23.0                                    OKC
#
#                                       Lg  \
# 0  Did Not Play (other pro league—Spain)
# 1                                    NBA
# 2                                    NBA
# 3                                    NBA
# 4                                    NBA
#
#                                      Pos  \
# 0  Did Not Play (other pro league—Spain)
# 1                                     PF
# 2                                     PF
# 3                                     PF
# 4                                     PF
#
#                                        G  \
# 0  Did Not Play (other pro league—Spain)
# ...

# %%
## HDFS =====> Hadoop Distributed File System

# %%
h5_data = pd.HDFStore('test.h5')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Pandas_1.ipynb',
#  'Pandas_2.ipynb',
#  'PLayers_NBA.csv',
#  'player_nba_pickle',
#  'test.h5']

# %%
## store data in df to h5_data onj1 instance
h5_data['obj1'] = df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['Season', 'Tm', 'Lg', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
type(h5_data['obj1'])
# Out:
# pandas.core.frame.DataFrame

# %%
h5_data['obj1'].head()
# Out:
#     Season   Age                                     Tm  \
# 0  2008-09  19.0  Did Not Play (other pro league—Spain)
# 1  2009-10  20.0                                    OKC
# 2  2010-11  21.0                                    OKC
# 3  2011-12  22.0                                    OKC
# 4  2012-13  23.0                                    OKC
#
#                                       Lg  \
# 0  Did Not Play (other pro league—Spain)
# 1                                    NBA
# 2                                    NBA
# 3                                    NBA
# 4                                    NBA
#
#                                      Pos  \
# 0  Did Not Play (other pro league—Spain)
# 1                                     PF
# 2                                     PF
# 3                                     PF
# 4                                     PF
#
#                                        G  \
# 0  Did Not Play (other pro league—Spain)
# ...

# %%
h5_data['obj1'].tail()
# Out:
#        Season  Age   Tm   Lg  Pos    G   GS    MP   FG   FGA  ...   FT%  ORB  \
# 20  7 seasons  NaN  OKC  NBA  NaN  524  413  28.8  4.9   9.3  ...  .745  2.4
# 21  4 seasons  NaN  TOR  NBA  NaN  228  177  27.6  5.8  11.4  ...  .768  1.7
# 22  2 seasons  NaN  LAC  NBA  NaN   76   49  19.6  3.7   7.3  ...  .768  1.5
# 23   1 season  NaN  ORL  NBA  NaN   56   56  30.5  6.1  12.6  ...  .846  1.8
# 24   1 season  NaN  MIL  NBA  NaN   19    2  17.8  2.8   5.5  ...  .800  1.2
#
#     DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 20  5.0  7.4  0.6  0.4  2.5  1.3  2.8  11.6
# 21  5.7  7.4  1.1  0.4  1.2  1.5  2.8  14.2
# 22  4.1  5.6  1.4  0.2  1.0  1.0  1.7   9.0
# 23  5.0  6.8  1.1  0.6  1.6  1.2  2.5  15.1
# 24  4.1  5.3  0.7  0.2  0.4  0.5  2.4   7.0
#
# [5 rows x 30 columns]

# %%
type(h5_data)
# Out:
# pandas.io.pytables.HDFStore

# %%
h5_data.put('obj2', df, format = 'table')

# %%
h5_data['obj2'].tail()
# Out:
#        Season  Age   Tm   Lg  Pos    G   GS    MP   FG   FGA  ...   FT%  ORB  \
# 20  7 seasons  NaN  OKC  NBA  NaN  524  413  28.8  4.9   9.3  ...  .745  2.4
# 21  4 seasons  NaN  TOR  NBA  NaN  228  177  27.6  5.8  11.4  ...  .768  1.7
# 22  2 seasons  NaN  LAC  NBA  NaN   76   49  19.6  3.7   7.3  ...  .768  1.5
# 23   1 season  NaN  ORL  NBA  NaN   56   56  30.5  6.1  12.6  ...  .846  1.8
# 24   1 season  NaN  MIL  NBA  NaN   19    2  17.8  2.8   5.5  ...  .800  1.2
#
#     DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 20  5.0  7.4  0.6  0.4  2.5  1.3  2.8  11.6
# 21  5.7  7.4  1.1  0.4  1.2  1.5  2.8  14.2
# 22  4.1  5.6  1.4  0.2  1.0  1.0  1.7   9.0
# 23  5.0  6.8  1.1  0.6  1.6  1.2  2.5  15.1
# 24  4.1  5.3  0.7  0.2  0.4  0.5  2.4   7.0
#
# [5 rows x 30 columns]

# %%
h5_data.select('obj2', where = ['index >= 10 and index <= 15'])
# Out:
#      Season   Age   Tm   Lg Pos   G  GS    MP   FG   FGA  ...   FT%  ORB  DRB  \
# 10  2016-17  27.0  TOR  NBA  PF  23  23  31.0  5.6  12.1  ...  .882  1.3  5.5
# 11  2017-18  28.0  TOR  NBA  PF  76  76  27.5  5.0  10.3  ...  .797  1.0  5.3
# 12  2018-19  29.0  TOR  NBA   C  74  51  27.2  6.3  11.9  ...  .763  2.1  6.0
# 13  2019-20  30.0  TOR  NBA   C  55  27  27.0  6.2  12.2  ...  .718  2.1  6.1
# 14  2020-21  31.0  LAC  NBA   C  41  39  23.3  4.5   8.9  ...  .811  1.8  4.9
# 15  2021-22  32.0  TOT  NBA   C  54  12  16.2  2.7   5.5  ...  .727  1.1  3.5
#
#     TRB  AST  STL  BLK  TOV   PF   PTS
# 10  6.8  0.7  0.3  1.4  1.7  3.3  14.2
# 11  6.3  0.8  0.4  1.3  1.2  2.8  12.6
# 12  8.1  1.3  0.4  1.4  1.5  2.9  15.0
# 13  8.2  1.4  0.5  0.8  2.0  2.8  15.4
# 14  6.7  1.8  0.2  1.1  1.1  1.9  11.1
# 15  4.6  0.9  0.2  0.6  0.8  1.9   6.8
#
# [6 rows x 30 columns]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
## get only those where dattyope is object
df.dtypes[df.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
type(df.dtypes[df.dtypes == 'object'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
type(df.dtypes[df.dtypes == 'object'].index)
# Out:
# pandas.core.indexes.base.Index

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
cols = df.dtypes[df.dtypes == 'object'].index

# %%
df1 = df[cols]

# %%
df1.head()
# Out:
#                                                 Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171   NaN        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282   NaN        S
# 3            113803  C123        S
# 4            373450   NaN        S

# %%
df1.describe()
# Out:
#                             Name   Sex  Ticket    Cabin Embarked
# count                        891   891     891      204      889
# unique                       891     2     681      147        3
# top     Wick, Miss. Mary Natalie  male  347082  B96 B98        S
# freq                           1   577       7        4      644

# %%
### filter cols with dtypes float

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes == float
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df.dtypes[df.dtypes == float]
# Out:
# Age     float64
# Fare    float64
# dtype: object

# %%
### here index is Age and fare and value is float64
## now select only index 

df.dtypes[df.dtypes == float].index
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
### now i have columns so need to write df[column_names]
df2 = df[df.dtypes[df.dtypes == float].index]

# %%
df2.head()
# Out:
#     Age     Fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
df2.describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df['Name'][5]
# Out:
# 'Moran, Mr. James'

# %%
df['Name'][5:10]
# Out:
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df['Name'][5:10:2]
# Out:
# 5                       Moran, Mr. James
# 7         Palsson, Master. Gosta Leonard
# 9    Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df['Ticket'][5:16]
# Out:
# 5        330877
# 6         17463
# 7        349909
# 8        347742
# 9        237736
# 10      PP 9549
# 11       113783
# 12    A/5. 2151
# 13       347082
# 14       350406
# 15       248706
# Name: Ticket, dtype: object

# %%
df[['Ticket']][5:16]
# Out:
#        Ticket
# 5      330877
# 6       17463
# 7      349909
# 8      347742
# 9      237736
# 10    PP 9549
# 11     113783
# 12  A/5. 2151
# 13     347082
# 14     350406
# 15     248706

# %%
###sorted result
sorted(df['Ticket'])
# Out:
# ['110152',
#  '110152',
#  '110152',
#  '110413',
#  '110413',
#  '110413',
#  '110465',
#  '110465',
#  '110564',
#  '110813',
#  '111240',
#  '111320',
#  '111361',
#  '111361',
#  '111369',
#  '111426',
#  '111427',
#  '111428',
#  '112050',
#  '112052',
#  '112053',
#  '112058',
#  '112059',
#  '112277',
#  '112379',
#  '113028',
#  '113043',
#  '113050',
#  '113051',
#  '113055',
#  '113056',
#  '113059',
#  '113501',
#  '113503',
#  '113505',
#  '113505',
#  '113509',
#  '113510',
#  '113514',
#  '113572',
#  '113572',
#  '113760',
#  '113760',
#  '113760',
#  '113760',
#  '113767',
#  '113773',
#  '113776',
#  '113776',
#  '113781',
#  '113781',
#  '113781',
#  '113781',
#  '113783',
#  '113784',
#  '113786',
#  '113787',
#  '113788',
#  '113789',
#  '113789',
#  '113792',
#  '113794',
#  '113796',
#  '113798',
#  '113798',
#  '113800',
#  '113803',
#  '113803',
#  '113804',
#  '113806',
#  '113806',
#  '113807',
#  '11668',
#  '11668',
#  '11751',
#  '11751',
#  '11752',
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
for i in df.columns:
    print(df[[i]])
# Out:
#      PassengerId
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ..           ...
# 886          887
# 887          888
# 888          889
# 889          890
# 890          891
#
# [891 rows x 1 columns]
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ...

# %%
### Add new column to df

df['sachin'] = 'Dev'

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked sachin
# 0      0         A/5 21171   7.2500   NaN        S    Dev
# 1      0          PC 17599  71.2833   C85        C    Dev
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Dev
# 3      0            113803  53.1000  C123        S    Dev
# ...

# %%
### copy data of passenger id to a new column sachin1
df['sachin1'] = df['PassengerId']

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked sachin  sachin1
# 0      0         A/5 21171   7.2500   NaN        S    Dev        1
# 1      0          PC 17599  71.2833   C85        C    Dev        2
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Dev        3
# ...

# %%
df['sachin1'][800:812]
# Out:
# 800    801
# 801    802
# 802    803
# 803    804
# 804    805
# 805    806
# 806    807
# 807    808
# 808    809
# 809    810
# 810    811
# 811    812
# Name: sachin1, dtype: int64

# %%
import pandas as pd

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked sachin  sachin1
# 0      0         A/5 21171   7.2500   NaN        S    Dev        1
# 1      0          PC 17599  71.2833   C85        C    Dev        2
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Dev        3
# ...

# %%
### here categories represent unique data 
pd.Categorical(df['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
pd.Categorical(df['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
### find if there is any Null data
df['Pclass'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Pclass, Length: 891, dtype: bool

# %%
df['Cabin'].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
### extract all indexes where we have null value

df['Cabin'][df['Cabin'].isnull() == True]
# Out:
# 0      NaN
# 2      NaN
# 4      NaN
# 5      NaN
# 7      NaN
#       ...
# 884    NaN
# 885    NaN
# 886    NaN
# 888    NaN
# 890    NaN
# Name: Cabin, Length: 687, dtype: object

# %%
df['Cabin'][df['Cabin'].isnull() == True].index
# Out:
# Int64Index([  0,   2,   4,   5,   7,   8,   9,  12,  13,  14,
#             ...
#             878, 880, 881, 882, 883, 884, 885, 886, 888, 890],
#            dtype='int64', length=687)

# %%
### extract all indexes where we have not null value
df['Cabin'][df['Cabin'].isnull() == False]
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
#           ...
# 871            D35
# 872    B51 B53 B55
# 879            C50
# 887            B42
# 889           C148
# Name: Cabin, Length: 204, dtype: object

# %%
ser = df['Cabin'][df['Cabin'].isnull() == False]

# %%
ser.index
# Out:
# Int64Index([  1,   3,   6,  10,  11,  21,  23,  27,  31,  52,
#             ...
#             849, 853, 857, 862, 867, 871, 872, 879, 887, 889],
#            dtype='int64', length=204)

# %%
### exract records ROW wise

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked sachin  sachin1
# 0      0  A/5 21171   7.2500   NaN        S    Dev        1
# 1      0   PC 17599  71.2833   C85        C    Dev        2

# %%
df.iloc[ser.index]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[[1,5,6,4,7,8]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 5            6         0       3
# 6            7         0       1
# 4            5         0       3
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 4                           Allen, Mr. William Henry    male  35.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch    Ticket     Fare Cabin Embarked sachin  sachin1
# 1      0  PC 17599  71.2833   C85        C    Dev        2
# 5      0    330877   8.4583   NaN        Q    Dev        6
# ...

# %%
ser = df['Cabin'][df['Cabin'].isnull() == True]

# %%
ser.index
# Out:
# Int64Index([  0,   2,   4,   5,   7,   8,   9,  12,  13,  14,
#             ...
#             878, 880, 881, 882, 883, 884, 885, 886, 888, 890],
#            dtype='int64', length=687)

# %%
df.iloc[ser.index]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
ser = df['Cabin'][df['Cabin'].isnull() == True]

# %%
len(ser)
# Out:
# 687

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
df[['Fare']].head()
# Out:
#       Fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500

# %%
### get the name of the passenger who paid highest fare
con = df['Fare'][df['Fare'] == max(df['Fare'])]

# %%
con
# Out:
# 258    512.3292
# 679    512.3292
# 737    512.3292
# Name: Fare, dtype: float64

# %%
con.index
# Out:
# Int64Index([258, 679, 737], dtype='int64')

# %%
df[['Name']].iloc[con.index]
# Out:
#                                    Name
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %%
### combine 2 columns and add to a new column
df['new_col'] = df['PassengerId'] + df['Age']

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked sachin  sachin1  new_col
# 0      0         A/5 21171   7.2500   NaN        S    Dev        1     23.0
# 1      0          PC 17599  71.2833   C85        C    Dev        2     40.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Dev        3     29.0
